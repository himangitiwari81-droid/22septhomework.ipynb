# %%
name = "himangi"

print(name[0],name[-1])
print(name[-7],name[6])
print(name[0],name[6])
print(name[-7],name[-1])
print(name[0],name[len(name)-1])
print(name[1-1],name[5+1])
print(name[-8+1],name[7-1])
print(name[2-2],name[3+3])
print(name[-9+2],name[4+2])
print(name[5-5],name[8-2])
# Out:
# h i
# h i
# h i
# h i
# h i
# h i
# h i
# h i
# h i
# h i
